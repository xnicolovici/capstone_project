# %% [markdown]
# EPFL Extension School - 2020/2022
#
# Capstone Project - Xavier Nicolovici

# %% [markdown]
# This capstone project will try to find a machine learning model to answer that question:
#
# **What are the Taxi travel speed prevision for New-York City (NYC) depending on the travel characteristics and weather forecast ?**
#
# The ML models will be trained to determine the speed in kilometers per hour a Taxi trip will take in New-York City, depending on travel characteristics like pickup and dropoff location, period of the day, of the week,... and weather characteristics like temperature of the day, rain, snow,...
#
# This model should help to determine the time that would take to go from one location to another in New-York using a Taxi cab.
#
# To achieve this, I will use a dataset taken from *Kaggle* and I'll extend it using weather dataset taken from the *National Centers for Environmental Information*.
#
# > Note: In the rest of this project, the *NYC* acronym will be used to name *Ney-York City*

# %% [markdown]
# # Time spent on this project
#
# As of the 1st of February 2022: 98 hours

# %% [markdown]
# # Datasets
#
# Two datasets will be used for this capstone project.
#
# ## NYC Taxi Travel Dataset
#
# This [NYC Taxi Travel](https://www.kaggle.com/yasserh/nyc-taxi-trip-duration) dataset has been found on Kaggle and was used in a competition where participants, based on individual trip attributes, should predict the duration of each trip in the test set. This dataset is based on the 2016 NYC Yellow Cab trip record data made available in [Big Query](https://cloud.google.com/bigquery) on Google Cloud Platform. The data was sampled and cleaned for the purposes of this playground competition.
#
# This dataset covers data from the 1st of January until the 30th of June 2016.
#
# Most of the cleaning work have been done on this dataset, which is good news for me :-)
#
# ## NYC Weeather informations
#
# To extend the previous dataset with weather informations, I've used the [Climate Data Search Engine](https://www.ncdc.noaa.gov/cdo-web/confirmation) from the *National Centers for Environmental Information*
#
# This search engine allows me to grab multiple weather informations concerning NYC, covering the period of the NYC Taxi Dataset.
#
# Merging those two datasets will lead to one dataset with travel informations along with weather ones.

# %% [markdown]
# # Organisation
#
# This project is organized in 4 big chapters:
#
# - Data preparation: Where datasets will be prepared and cleaned
# - Data Exploration: Where data will be explored and improved
# - Machine learning models: Where ML models will be trained
# - Results and Communication: Where ML models results will be presented and anlyzed
#
# Those big chapters are contained in Notebooks which names starts by, respectively, 10, 20, 30 and 40. Any sub-Notebooks needed for one of this chapter will be numbered with the number of the chapter + 1. For example:
#
# 10 - Data preparation
#
# 11 - Data preparation - NYC Taxi dataset
#
# 12 - Data preparation - NYC Weather dataset

# %% [markdown]
# # Technics

# %% [markdown]
# ## GeoPandas
#
# At this time of writing, I'm not sure to have time to explore this wonderful library [GeoPandas](https://geopandas.org/en/stable/).
#
# This library provides Pandas Dataframe and Series extension classes to draw maps along with datapoint. This might be very nice and usefull to represent pickup and dropoff point, weather stations zone and other geographic features.
#
# >Note: Be sure to execute the following instruction to ensure that GeoPandas library is available in your Jupyter Notebook environment.

# %%
# !pip install shapely fiona pyproj geopandas

# %% [markdown]
# In order to validate that the GeoPandas library as been correctly installed, let's draw a small map of south America.
#
# This code snippet has been copied from the [GeoPandas website](https://geopandas.org/en/stable/gallery/create_geopandas_from_pandas.html).
#
# > Note: If you get any error here, then the GeoPandas feature has not been correctly installed. This might lead to errors while running Notebooks of this project

# %%
import pandas as pd
import geopandas
import matplotlib.pyplot as plt

df = pd.DataFrame(
    {'City': ['Buenos Aires', 'Brasilia', 'Santiago', 'Bogota', 'Caracas'],
     'Country': ['Argentina', 'Brazil', 'Chile', 'Colombia', 'Venezuela'],
     'Latitude': [-34.58, -15.78, -33.45, 4.60, 10.48],
     'Longitude': [-58.66, -47.91, -70.66, -74.08, -66.86]})

gdf = geopandas.GeoDataFrame(
    df, geometry=geopandas.points_from_xy(df.Longitude, df.Latitude))

world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

# We restrict to South America.
ax = world[world.continent == 'South America'].plot(
    color='white', edgecolor='black')

# We can now plot our ``GeoDataFrame``.
gdf.plot(ax=ax, color='red')

plt.show()

# %% [markdown]
# ## my_utils.ipynb
#
# In order to simplify the code in the different Notebooks, many usefull functions will be coded into a Notebook named [my_utils.py](my_utils.ipynb)
#
# Prior to using this import approach, be sure that the [ipynb](https://ipynb.readthedocs.io/en/stable/) module is installed on your Python environment by running the following instruction.

# %%
# Ensure that 'ipynb' module exists in the Python env
# !pip install ipynb

# %% [markdown]
# Then, in order to use any function defined in *my_utils.ipynb*, each Notebooks of this project will start with the following code:

# %%
# Load my_utils.ipynb in Notebook
from ipynb.fs.full.my_utils import *
# Out:
# Opening connection to database
# Add pythagore() function to SQLite engine
# Fraction of the dataset used to train models: 10.00%
# my_utils library loaded :-)

# %% [markdown]
# Details of the functions available in [my_utils](my_utils.ipynb) can be found in the file itself as Python embeded comments

# %% [markdown]
# ## Map of New-York City
#
# In order to draw the map of New-York City, I've decided to use a shape definition available on the [University of Texas at Austin website](https://geodata.lib.utexas.edu)
#
# The shape I've used is the [2010 New York City Boroughs](https://geodata.lib.utexas.edu/catalog/nyu-2451-34490) and here is how it looks:
#
# > Note: The function I use here is coded in the [my_utils](my_utils.ipynb) library and accept optional parameters like latitude/longitude series to be plotted along with the map

# %%
# Draw NYC map with two optional locations
draw_nyc_map(latitude=[40.65, 40.6], longitude=[-74, -73.9])

# %% [markdown]
# # Let's Go
# Time to start my journey in this Capstone project with the next notebook: [Data Preparation Introduction](10.Data%20Preparation%20Introduction.ipynb)
